# %% [markdown]
# Data setler ile calismayi ögreniyorum
#
# -> Titanic yolcu listesi ile ne bok yapicam bilmiyorum ama planlarim; ölenlerin Listesi, hayatta kalanlarin listesi. Yolcularin yas ortalamasi,ölenlerin, Hayatta kalanlarin, hayatta kalma ihtimali kacti cart curt.

# %%
import pandas as pd 
import numpy as np

titanic_list = pd.read_csv("titanic.csv")


titanic_list
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
#Isim, yas  ve cabin listesi ;
titanic_Name_Age = pd.read_csv("titanic.csv",usecols= [5, 3, 4], index_col= False)


titanic_Name_Age
# Out:
#                                                   Name     Sex   Age
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
# [891 rows x 3 columns]

# %%
titanic_list.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_list.iat[3, 3]

#spesifik cell in degerini veriyo hmmmmmm
# Out:
# 'Futrelle, Mrs. Jacques Heath (Lily May Peel)'

# %%
titanic_list[['Name', 'Age', "Sex"]]
# Out:
#                                                   Name   Age     Sex
# 0                              Braund, Mr. Owen Harris  22.0    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                               Heikkinen, Miss. Laina  26.0  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                             Allen, Mr. William Henry  35.0    male
# ..                                                 ...   ...     ...
# 886                              Montvila, Rev. Juozas  27.0    male
# 887                       Graham, Miss. Margaret Edith  19.0  female
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN  female
# 889                              Behr, Mr. Karl Howell  26.0    male
# 890                                Dooley, Mr. Patrick  32.0    male
#
# [891 rows x 3 columns]

# %%
#yolcularin yas ortlamasi
titanic_list[["Age"]].mean().astype(int)
# Out:
# Age    29
# dtype: int64

# %%
# Erkeklerin ve kadinlarin yas ortalamasi ? 

boys = titanic_list[titanic_list["Sex"]== "male"]

girls = titanic_list[titanic_list["Sex"]== "female"]

girls
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 882                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 880      1            230433  26.0000   NaN        S
# 882      0              7552  10.5167   NaN        S
# 885      5            382652  29.1250   NaN        Q
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
#
# [314 rows x 12 columns]

# %%
#kadin yolcularin yas ortalamasi 

girls["Age"].mean().astype(int)
# Out:
# 27

# %%
#erkek yolcularin yas ortalamasi 

boys["Age"].mean().astype(int)
# Out:
# 30

# %%
# ded or not check ? -> nasil yapicagimi bilmiyorum
titanic_list.iat[1, 1]

#bunu beceremicem, next
# Out:
# 1

# %%
#survive edenlerin liste
not_dead = titanic_list.where(titanic_list["Survived"] > 0)

not_dead
# Out:
#      PassengerId  Survived  Pclass  \
# 0            NaN       NaN     NaN
# 1            2.0       1.0     1.0
# 2            3.0       1.0     3.0
# 3            4.0       1.0     1.0
# 4            NaN       NaN     NaN
# ..           ...       ...     ...
# 886          NaN       NaN     NaN
# 887        888.0       1.0     1.0
# 888          NaN       NaN     NaN
# 889        890.0       1.0     1.0
# 890          NaN       NaN     NaN
#
#                                                   Name     Sex   Age  SibSp  \
# 0                                                  NaN     NaN   NaN    NaN
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                               Heikkinen, Miss. Laina  female  26.0    0.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                                                  NaN     NaN   NaN    NaN
# ..                                                 ...     ...   ...    ...
# 886                                                NaN     NaN   NaN    NaN
# 887                       Graham, Miss. Margaret Edith  female  19.0    0.0
# 888                                                NaN     NaN   NaN    NaN
# 889                              Behr, Mr. Karl Howell    male  26.0    0.0
# 890                                                NaN     NaN   NaN    NaN
#
#      Parch            Ticket     Fare Cabin Embarked
# 0      NaN               NaN      NaN   NaN      NaN
# 1      0.0          PC 17599  71.2833   C85        C
# 2      0.0  STON/O2. 3101282   7.9250   NaN        S
# 3      0.0            113803  53.1000  C123        S
# 4      NaN               NaN      NaN   NaN      NaN
# ..     ...               ...      ...   ...      ...
# 886    NaN               NaN      NaN   NaN      NaN
# 887    0.0            112053  30.0000   B42        S
# 888    NaN               NaN      NaN   NaN      NaN
# 889    0.0            111369  30.0000  C148        C
# 890    NaN               NaN      NaN   NaN      NaN
#
# [891 rows x 12 columns]

# %%
#Hayatta kalanlarin yas ortalamsi 

not_dead["Age"].mean().astype(int)
# Out:
# 28

# %%
titanic_list.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_list["Cabin"]
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
#Stack overflowdan caldim
Cabin_ignnored_non = titanic_list[titanic_list['Cabin'].notna().groupby(titanic_list['Name']).cummax()]
Cabin_ignnored_non
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 10       1   PP 9549  16.7000           G6        S
# 11       0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [204 rows x 12 columns]

# %%
Cabin_ignnored_non["Cabin"]
# Out:
# 1              C85
# 3             C123
# 6              E46
# 10              G6
# 11            C103
#           ...
# 871            D35
# 872    B51 B53 B55
# 879            C50
# 887            B42
# 889           C148
# Name: Cabin, Length: 204, dtype: object

# %%
#Isim_cain = titanic_list["Name"].groupby([Cabin_ignnored_non["Cabin"]])
#Isim_cain

#anlamadim bu olayi

# %%
Cabin_ignnored_non[["Cabin", "Name"]].style.set_caption("Cabin Number")
# Out:
# <style type="text/css">
# </style>
# <table id="T_7e122">
#   <caption>Cabin Number</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e122_level0_col0" class="col_heading level0 col0" >Cabin</th>
#       <th id="T_7e122_level0_col1" class="col_heading level0 col1" >Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e122_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_7e122_row0_col0" class="data row0 col0" >C85</td>
#       <td id="T_7e122_row0_col1" class="data row0 col1" >Cumings, Mrs. John Bradley (Florence Briggs Thayer)</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_7e122_row1_col0" class="data row1 col0" >C123</td>
#       <td id="T_7e122_row1_col1" class="data row1 col1" >Futrelle, Mrs. Jacques Heath (Lily May Peel)</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_7e122_row2_col0" class="data row2 col0" >E46</td>
#       <td id="T_7e122_row2_col1" class="data row2 col1" >McCarthy, Mr. Timothy J</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row3" class="row_heading level0 row3" >10</th>
#       <td id="T_7e122_row3_col0" class="data row3 col0" >G6</td>
#       <td id="T_7e122_row3_col1" class="data row3 col1" >Sandstrom, Miss. Marguerite Rut</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row4" class="row_heading level0 row4" >11</th>
#       <td id="T_7e122_row4_col0" class="data row4 col0" >C103</td>
#       <td id="T_7e122_row4_col1" class="data row4 col1" >Bonnell, Miss. Elizabeth</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row5" class="row_heading level0 row5" >21</th>
#       <td id="T_7e122_row5_col0" class="data row5 col0" >D56</td>
#       <td id="T_7e122_row5_col1" class="data row5 col1" >Beesley, Mr. Lawrence</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row6" class="row_heading level0 row6" >23</th>
#       <td id="T_7e122_row6_col0" class="data row6 col0" >A6</td>
#       <td id="T_7e122_row6_col1" class="data row6 col1" >Sloper, Mr. William Thompson</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row7" class="row_heading level0 row7" >27</th>
#       <td id="T_7e122_row7_col0" class="data row7 col0" >C23 C25 C27</td>
#       <td id="T_7e122_row7_col1" class="data row7 col1" >Fortune, Mr. Charles Alexander</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row8" class="row_heading level0 row8" >31</th>
#       <td id="T_7e122_row8_col0" class="data row8 col0" >B78</td>
#       <td id="T_7e122_row8_col1" class="data row8 col1" >Spencer, Mrs. William Augustus (Marie Eugenie)</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row9" class="row_heading level0 row9" >52</th>
#       <td id="T_7e122_row9_col0" class="data row9 col0" >D33</td>
#       <td id="T_7e122_row9_col1" class="data row9 col1" >Harper, Mrs. Henry Sleeper (Myna Haxtun)</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row10" class="row_heading level0 row10" >54</th>
#       <td id="T_7e122_row10_col0" class="data row10 col0" >B30</td>
#       <td id="T_7e122_row10_col1" class="data row10 col1" >Ostby, Mr. Engelhart Cornelius</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row11" class="row_heading level0 row11" >55</th>
#       <td id="T_7e122_row11_col0" class="data row11 col0" >C52</td>
#       <td id="T_7e122_row11_col1" class="data row11 col1" >Woolner, Mr. Hugh</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row12" class="row_heading level0 row12" >61</th>
#       <td id="T_7e122_row12_col0" class="data row12 col0" >B28</td>
#       <td id="T_7e122_row12_col1" class="data row12 col1" >Icard, Miss. Amelie</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row13" class="row_heading level0 row13" >62</th>
#       <td id="T_7e122_row13_col0" class="data row13 col0" >C83</td>
#       <td id="T_7e122_row13_col1" class="data row13 col1" >Harris, Mr. Henry Birkhardt</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row14" class="row_heading level0 row14" >66</th>
#       <td id="T_7e122_row14_col0" class="data row14 col0" >F33</td>
#       <td id="T_7e122_row14_col1" class="data row14 col1" >Nye, Mrs. (Elizabeth Ramell)</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row15" class="row_heading level0 row15" >75</th>
#       <td id="T_7e122_row15_col0" class="data row15 col0" >F G73</td>
#       <td id="T_7e122_row15_col1" class="data row15 col1" >Moen, Mr. Sigurd Hansen</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row16" class="row_heading level0 row16" >88</th>
#       <td id="T_7e122_row16_col0" class="data row16 col0" >C23 C25 C27</td>
#       <td id="T_7e122_row16_col1" class="data row16 col1" >Fortune, Miss. Mabel Helen</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row17" class="row_heading level0 row17" >92</th>
#       <td id="T_7e122_row17_col0" class="data row17 col0" >E31</td>
#       <td id="T_7e122_row17_col1" class="data row17 col1" >Chaffee, Mr. Herbert Fuller</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row18" class="row_heading level0 row18" >96</th>
#       <td id="T_7e122_row18_col0" class="data row18 col0" >A5</td>
#       <td id="T_7e122_row18_col1" class="data row18 col1" >Goldschmidt, Mr. George B</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row19" class="row_heading level0 row19" >97</th>
#       <td id="T_7e122_row19_col0" class="data row19 col0" >D10 D12</td>
#       <td id="T_7e122_row19_col1" class="data row19 col1" >Greenfield, Mr. William Bertram</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row20" class="row_heading level0 row20" >102</th>
#       <td id="T_7e122_row20_col0" class="data row20 col0" >D26</td>
#       <td id="T_7e122_row20_col1" class="data row20 col1" >White, Mr. Richard Frasar</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row21" class="row_heading level0 row21" >110</th>
#       <td id="T_7e122_row21_col0" class="data row21 col0" >C110</td>
#       <td id="T_7e122_row21_col1" class="data row21 col1" >Porter, Mr. Walter Chamberlain</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row22" class="row_heading level0 row22" >118</th>
#       <td id="T_7e122_row22_col0" class="data row22 col0" >B58 B60</td>
#       <td id="T_7e122_row22_col1" class="data row22 col1" >Baxter, Mr. Quigg Edmond</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row23" class="row_heading level0 row23" >123</th>
#       <td id="T_7e122_row23_col0" class="data row23 col0" >E101</td>
#       <td id="T_7e122_row23_col1" class="data row23 col1" >Webber, Miss. Susan</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row24" class="row_heading level0 row24" >124</th>
#       <td id="T_7e122_row24_col0" class="data row24 col0" >D26</td>
#       <td id="T_7e122_row24_col1" class="data row24 col1" >White, Mr. Percival Wayland</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row25" class="row_heading level0 row25" >128</th>
#       <td id="T_7e122_row25_col0" class="data row25 col0" >F E69</td>
#       <td id="T_7e122_row25_col1" class="data row25 col1" >Peter, Miss. Anna</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row26" class="row_heading level0 row26" >136</th>
#       <td id="T_7e122_row26_col0" class="data row26 col0" >D47</td>
#       <td id="T_7e122_row26_col1" class="data row26 col1" >Newsom, Miss. Helen Monypeny</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row27" class="row_heading level0 row27" >137</th>
#       <td id="T_7e122_row27_col0" class="data row27 col0" >C123</td>
#       <td id="T_7e122_row27_col1" class="data row27 col1" >Futrelle, Mr. Jacques Heath</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row28" class="row_heading level0 row28" >139</th>
#       <td id="T_7e122_row28_col0" class="data row28 col0" >B86</td>
#       <td id="T_7e122_row28_col1" class="data row28 col1" >Giglio, Mr. Victor</td>
#     </tr>
#     <tr>
#       <th id="T_7e122_level0_row29" class="row_heading level0 row29" >148</th>
#       <td id="T_7e122_row29_col0" class="data row29 col0" >F2</td>
#       <td id="T_7e122_row29_col1" class="data row29 co

# %% [markdown]
# Simdi cabin bilgisi olmayanlari bulucam

# %%
Cabin_info_non1 = titanic_list[titanic_list['Cabin'].notna().groupby(titanic_list['Name']).cummax()]

Cabin_info_non1
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 10       1   PP 9549  16.7000           G6        S
# 11       0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [204 rows x 12 columns]

# %%
Cabin_info_non = titanic_list[titanic_list["Cabin"].isnull()]

Cabin_info_non
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# 5      male   NaN      0      0            330877   8.4583   NaN        Q
# 7      male   2.0      3      1            349909  21.0750   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [687 rows x 12 columns]

# %%
Cabin_info_non[["Name", "Cabin"]].style.set_caption("Cabin Unknown")
# Out:
# <style type="text/css">
# </style>
# <table id="T_b417c">
#   <caption>Cabin Unknown</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b417c_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_b417c_level0_col1" class="col_heading level0 col1" >Cabin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b417c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b417c_row0_col0" class="data row0 col0" >Braund, Mr. Owen Harris</td>
#       <td id="T_b417c_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_b417c_row1_col0" class="data row1 col0" >Heikkinen, Miss. Laina</td>
#       <td id="T_b417c_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_b417c_row2_col0" class="data row2 col0" >Allen, Mr. William Henry</td>
#       <td id="T_b417c_row2_col1" class="data row2 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_b417c_row3_col0" class="data row3 col0" >Moran, Mr. James</td>
#       <td id="T_b417c_row3_col1" class="data row3 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_b417c_row4_col0" class="data row4 col0" >Palsson, Master. Gosta Leonard</td>
#       <td id="T_b417c_row4_col1" class="data row4 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row5" class="row_heading level0 row5" >8</th>
#       <td id="T_b417c_row5_col0" class="data row5 col0" >Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)</td>
#       <td id="T_b417c_row5_col1" class="data row5 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_b417c_row6_col0" class="data row6 col0" >Nasser, Mrs. Nicholas (Adele Achem)</td>
#       <td id="T_b417c_row6_col1" class="data row6 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row7" class="row_heading level0 row7" >12</th>
#       <td id="T_b417c_row7_col0" class="data row7 col0" >Saundercock, Mr. William Henry</td>
#       <td id="T_b417c_row7_col1" class="data row7 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row8" class="row_heading level0 row8" >13</th>
#       <td id="T_b417c_row8_col0" class="data row8 col0" >Andersson, Mr. Anders Johan</td>
#       <td id="T_b417c_row8_col1" class="data row8 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row9" class="row_heading level0 row9" >14</th>
#       <td id="T_b417c_row9_col0" class="data row9 col0" >Vestrom, Miss. Hulda Amanda Adolfina</td>
#       <td id="T_b417c_row9_col1" class="data row9 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row10" class="row_heading level0 row10" >15</th>
#       <td id="T_b417c_row10_col0" class="data row10 col0" >Hewlett, Mrs. (Mary D Kingcome) </td>
#       <td id="T_b417c_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row11" class="row_heading level0 row11" >16</th>
#       <td id="T_b417c_row11_col0" class="data row11 col0" >Rice, Master. Eugene</td>
#       <td id="T_b417c_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row12" class="row_heading level0 row12" >17</th>
#       <td id="T_b417c_row12_col0" class="data row12 col0" >Williams, Mr. Charles Eugene</td>
#       <td id="T_b417c_row12_col1" class="data row12 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row13" class="row_heading level0 row13" >18</th>
#       <td id="T_b417c_row13_col0" class="data row13 col0" >Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)</td>
#       <td id="T_b417c_row13_col1" class="data row13 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row14" class="row_heading level0 row14" >19</th>
#       <td id="T_b417c_row14_col0" class="data row14 col0" >Masselmani, Mrs. Fatima</td>
#       <td id="T_b417c_row14_col1" class="data row14 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row15" class="row_heading level0 row15" >20</th>
#       <td id="T_b417c_row15_col0" class="data row15 col0" >Fynney, Mr. Joseph J</td>
#       <td id="T_b417c_row15_col1" class="data row15 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row16" class="row_heading level0 row16" >22</th>
#       <td id="T_b417c_row16_col0" class="data row16 col0" >McGowan, Miss. Anna "Annie"</td>
#       <td id="T_b417c_row16_col1" class="data row16 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row17" class="row_heading level0 row17" >24</th>
#       <td id="T_b417c_row17_col0" class="data row17 col0" >Palsson, Miss. Torborg Danira</td>
#       <td id="T_b417c_row17_col1" class="data row17 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row18" class="row_heading level0 row18" >25</th>
#       <td id="T_b417c_row18_col0" class="data row18 col0" >Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)</td>
#       <td id="T_b417c_row18_col1" class="data row18 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row19" class="row_heading level0 row19" >26</th>
#       <td id="T_b417c_row19_col0" class="data row19 col0" >Emir, Mr. Farred Chehab</td>
#       <td id="T_b417c_row19_col1" class="data row19 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row20" class="row_heading level0 row20" >28</th>
#       <td id="T_b417c_row20_col0" class="data row20 col0" >O'Dwyer, Miss. Ellen "Nellie"</td>
#       <td id="T_b417c_row20_col1" class="data row20 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row21" class="row_heading level0 row21" >29</th>
#       <td id="T_b417c_row21_col0" class="data row21 col0" >Todoroff, Mr. Lalio</td>
#       <td id="T_b417c_row21_col1" class="data row21 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row22" class="row_heading level0 row22" >30</th>
#       <td id="T_b417c_row22_col0" class="data row22 col0" >Uruchurtu, Don. Manuel E</td>
#       <td id="T_b417c_row22_col1" class="data row22 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row23" class="row_heading level0 row23" >32</th>
#       <td id="T_b417c_row23_col0" class="data row23 col0" >Glynn, Miss. Mary Agatha</td>
#       <td id="T_b417c_row23_col1" class="data row23 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row24" class="row_heading level0 row24" >33</th>
#       <td id="T_b417c_row24_col0" class="data row24 col0" >Wheadon, Mr. Edward H</td>
#       <td id="T_b417c_row24_col1" class="data row24 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row25" class="row_heading level0 row25" >34</th>
#       <td id="T_b417c_row25_col0" class="data row25 col0" >Meyer, Mr. Edgar Joseph</td>
#       <td id="T_b417c_row25_col1" class="data row25 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row26" class="row_heading level0 row26" >35</th>
#       <td id="T_b417c_row26_col0" class="data row26 col0" >Holverson, Mr. Alexander Oskar</td>
#       <td id="T_b417c_row26_col1" class="data row26 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row27" class="row_heading level0 row27" >36</th>
#       <td id="T_b417c_row27_col0" class="data row27 col0" >Mamee, Mr. Hanna</td>
#       <td id="T_b417c_row27_col1" class="data row27 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row28" class="row_heading level0 row28" >37</th>
#       <td id="T_b417c_row28_col0" class="data row28 col0" >Cann, Mr. Ernest Charles</td>
#       <td id="T_b417c_row28_col1" class="data row28 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_b417c_level0_row29" class="row_heading level0 row29" >38</th>
#       <td id="T_b417c_row29_col0" class="data row29 col0" >Vander Planke, Miss. Augusta Maria</td>
#       <td id="T_b417c_row29_col1" class="data row29 col

# %%
display(Cabin_info_non, Cabin_ignnored_non).style.set_caption("Hello World")
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# 5      male   NaN      0      0            330877   8.4583   NaN        Q
# 7      male   2.0      3      1            349909  21.0750   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [687 rows x 12 columns]
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 10       1   PP 9549  16.7000           G6        S
# 11       0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [204 rows x 12 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[219], line 1
# ----> 1 display(Cabin_info_non, Cabin_ignnored_non).style.set_caption("Hello World")
#
# AttributeError: 'NoneType' object has no attribute 'style'
